# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/README.txt
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/test_poses.csv
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229141957_0070_V.JPG
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229141916_0034_V.JPG
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229142726_0353_V.JPG
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229142252_0195_V.JPG
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229142648_0329_V.JPG
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/test/images/DJI_20241229142820_0390_V.JPG
# ...

# %%
# !git clone --branch demo https://github.com/LeeDerHerbsjaune/Kamikaze_BTS_2026_AIRace.git
# %cd Kamikaze_BTS_2026_AIRace/Telecom-DigitalTwin-fixed/Telecom-DigitalTwin
# Out:
# Cloning into 'Kamikaze_BTS_2026_AIRace'...
# remote: Enumerating objects: 796, done.
# remote: Counting objects: 100% (796/796), done.
# remote: Compressing objects: 100% (519/519), done.
# remote: Total 796 (delta 330), reused 593 (delta 159), pack-reused 0 (from 0)
# Receiving objects: 100% (796/796), 7.53 MiB | 5.11 MiB/s, done.
# Resolving deltas: 100% (330/330), done.
# /kaggle/working/Kamikaze_BTS_2026_AIRace/Telecom-DigitalTwin-fixed/Telecom-DigitalTwin

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 98.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

for root, dirs, files in os.walk("/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0181/train"):
    if "images" in dirs and "sparse" in dirs:
        print(root)
# Out:
# /kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0181/train

# %%
# !python train.py --config configs/default.kaggle.yaml
# Out:
# [2026-07-21 13:08:45] Starting experiment: bts_scene_01
# [2026-07-21 13:08:45] Loading dataset (drone images + camera poses)...
# [ColmapLoader] Filtered out 32624/224928 noisy points.
# [BTSDataset] WARNING: 131/371 images are listed in the sparse reconstruction but were NOT found in '/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0181/train/images': DJI_20241229103340_0026_V.JPG, DJI_20241229103341_0027_V.JPG, DJI_20241229103342_0028_V.JPG, DJI_20241229103346_0032_V.JPG, DJI_20241229103355_0037_V.JPG, ... (+126 more)
# These images are SKIPPED from the train/eval split (this is not a code bug - check the source dataset if the number missing is unexpectedly large).
# [2026-07-21 13:09:03] Train views: 216, Eval views: 24, Target novel views: 60
# Saved camera trajectory plot: /kaggle/working/outputs/bts_scene_01/camera_trajectory.png
# [2026-07-21 13:09:04] Initializing Gaussian Model from the point cloud...
# ...

# %%
# !python -m inference.render_novel_views --config configs/default.kaggle.yaml --checkpoint /kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth
# Out:
# usage: render_novel_views.py [-h] [--config CONFIG]
# render_novel_views.py: error: unrecognized arguments: --checkpoint /kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth
