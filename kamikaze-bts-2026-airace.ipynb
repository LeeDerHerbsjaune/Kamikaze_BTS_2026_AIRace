# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000260.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000005.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000560.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000500.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000335.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_001160.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000885.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/images/frame_000585.jpg
# /kaggle/input/datasets/lthuhong/round2/chair/train/sparse/0/frames.bin
# /kaggle/input/datasets/lthuhong/round2/chair/train/sparse/0/points3D.bin
# /kaggle/input/datasets/lthuhong/round2/chair/train/sparse/0/cameras.bin
# /kaggle/input/datasets/lthuhong/round2/chair/train/sparse/0/images.bin
# /kaggle/input/datasets/lthuhong/round2/chair/train/sparse/0/rigs.bin

# %%
# !git clone --branch honbell https://github.com/LeeDerHerbsjaune/Kamikaze_BTS_2026_AIRace.git
# %cd Kamikaze_BTS_2026_AIRace
# Out:
# Cloning into 'Kamikaze_BTS_2026_AIRace'...
# remote: Enumerating objects: 1146, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 1146 (delta 130), reused 159 (delta 100), pack-reused 934 (from 1)
# Receiving objects: 100% (1146/1146), 8.70 MiB | 20.11 MiB/s, done.
# Resolving deltas: 100% (542/542), done.
# /kaggle/working/Kamikaze_BTS_2026_AIRace

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.25.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.13.0.92)
# Collecting pycolmap (from -r requirements.txt (line 6))
#   Downloading pycolmap-4.1.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (6.0.3)
# Collecting plyfile (from -r requirements.txt (line 9))
#   Downloading plyfile-1.1.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Collecting lpips (from -r requirements.txt (line 11))
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.37.3)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (2.20.0)
# Collecting gsplat (from -r requirements.txt (line 15))
#   Downloading gsplat-1.5.3-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips->-r requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 14)) (3.1.8)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from gsplat->-r requirements.txt (line 15)) (1.13.0)
# Collecting jaxtyping (from gsplat->-r requirements.txt (line 15))
#   Downloading jaxtyping-0.3.11-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.12/dist-packages (from gsplat->-r requirements.txt (line 15)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->gsplat->-r requirements.txt (line 15)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->gsplat->-r requirements.txt (line 15)) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 14)) (3.0.3)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping->gsplat->-r requirements.txt (line 15))
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12->gsplat->-r requirements.txt (line 15)) (0.1.2)
# Downloading pycolmap-4.1.1-cp312-cp312-manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 66.7 MB/s eta 0:00:00
# Downloading plyfile-1.1.4-py3-none-any.whl (36 kB)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.7 MB/s eta 0:00:00
# Downloading gsplat-1.5.3-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 119.5 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.11-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.6 MB/s eta 0:00:00
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Installing collected packages: wadler-lindig, pycolmap, plyfile, jaxtyping, gsplat, lpips
# Successfully installed gsplat-1.5.3 jaxtyping-0.3.11 lpips-0.1.4 plyfile-1.1.4 pycolmap-4.1.1 wadler-lindig-0.1.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

print("🔍 Đang tìm kiếm thư mục 'root' phù hợp trong /kaggle/input...\n")

matching_roots = []

# Duyệt qua toàn bộ /kaggle/input
for root, dirs, files in os.walk("/kaggle/input"):
    # Kiểm tra nếu thư mục hiện tại chứa cả thư mục con 'images' và 'sparse'
    if "images" in dirs and "sparse" in dirs:
        matching_roots.append(root)

if matching_roots:
    print("✅ Đã tìm thấy đường dẫn root thích hợp:")
    for path in matching_roots:
        print("-" * 50)
        print(f'dataset:\n  root: "{path}"')
        print("-" * 50)
else:
    print("⚠️ Không tìm thấy thư mục nào chứa đồng thời cả 'images' và 'sparse'.")
    print("Dưới đây là toàn bộ cấu trúc thư mục trong /kaggle/input để bạn kiểm tra:\n")
    for root, dirs, files in os.walk("/kaggle/input"):
        print(root)
# Out:
# 🔍 Đang tìm kiếm thư mục 'root' phù hợp trong /kaggle/input...
#
# ✅ Đã tìm thấy đường dẫn root thích hợp:
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0204/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0181/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/HCM0193/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/hcm0034/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/public_set/hcm0031/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HNI0437/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HNI0366/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HCM0249/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HCM0254/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HCM0276/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HCM1439/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HNI0265/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/airace2026-round-1/phase1/private_set1/HNI0131/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0644/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0674/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0421/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/bonsai/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0540/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0539/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/chair/train"
# --------------------------------------------------

# %%
# !python train.py --config configs/default.kaggle.yaml
# Out:
# [2026-07-27 09:44:18] Starting experiment: bts_scene_01
# [2026-07-27 09:44:19] Loading dataset (drone images + camera poses)...
# [ColmapLoader] Filtered out 33486/218846 noisy points.
# [BTSDataset] WARNING: 158/398 images are listed in the sparse reconstruction but were NOT found in '/kaggle/input/datasets/lthuhong/round2/HCM0539/train/images': DJI_20241229165804_0012_V.JPG, DJI_20241229165813_0021_V.JPG, DJI_20241229165814_0022_V.JPG, DJI_20241229165817_0025_V.JPG, DJI_20241229165818_0026_V.JPG, ... (+153 more)
# These images are SKIPPED from the train/eval split (this is not a code bug - check the source dataset if the number missing is unexpectedly large).
# [2026-07-27 09:44:34] Train views: 216, Eval views: 24, Target novel views: 60
# Saved camera trajectory plot: /kaggle/working/outputs/bts_scene_01/camera_trajectory.png
# [2026-07-27 09:44:35] Initializing Gaussian Model from the point cloud...
# [2026-07-27 09:44:42] Initialized 185360 Gaussians
# Training:   0%|                                       | 0/50000 [00:00<?, ?it/s][2026-07-27 09:44:47] Starting training: 50000 iterations, 185360 initial Gaussians, 216 train views, 24 eval views, backend=gsplat, densify=on.
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (●     ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ( ●    ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (  ●   ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (   ●  ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (     ●) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# (    ● ) gsplat: Setting up CUDA with MAX_JOBS=10 (This may take a few minutes
# ...
# Training:  98%|▉| 48997/50000 [51:24<00:50, 20.06it/s, loss=0.0884, n_gaussians=[2026-07-27 10:36:12] [progress] iter 49000/50000 | loss=0.0884 | n_gaussians=130073 | 19.76 it/s | ETA=0:00:50 | lr_xyz=1.75e-06
# Training:  98%|▉| 49047/50000 [51:26<00:47, 19.89it/s, loss=0.136, n_gaussians=1[2026-07-27 10:36:14] [progress] iter 49050/50000 | loss=0.1356 | n_gaussians=130073 | 20.20 it/s | ETA=0:00:47 | lr_xyz=1.75e-06
# Training:  98%|▉| 49098/50000 [51:29<00:45, 19.64it/s, loss=0.136, n_gaussians=1[2026-07-27 10:36:17] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  98%|▉| 49098/50000 [51:29<00:45, 19.64it/s, loss=0.094, n_gaussians=1[2026-07-27 10:36:17] [progress] iter 49100/50000 | loss=0.0940 | n_gaussians=130073 | 19.71 it/s | ETA=0:00:45 | lr_xyz=1.75e-06
# Training:  98%|▉| 49148/50000 [51:31<00:42, 20.11it/s, loss=0.0976, n_gaussians=[2026-07-27 10:36:19] [progress] iter 49150/50000 | loss=0.0976 | n_gaussians=130073 | 20.32 it/s | ETA=0:00:41 | lr_xyz=1.75e-06
# Training:  98%|▉| 49198/50000 [51:34<00:40, 19.98it/s, loss=0.0976, n_gaussians=[2026-07-27 10:36:22] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  98%|▉| 49198/50000 [51:34<00:40, 19.98it/s, loss=0.0884, n_gaussians=[2026-07-27 10:36:22] [progress] iter 49200/50000 | loss=0.0884 | n_gaussians=130073 | 19.71 it/s | ETA=0:00:40 | lr_xyz=1.75e-06
# Training:  98%|▉| 49248/50000 [51:36<00:37, 20.04it/s, loss=0.143, n_gaussians=1[2026-07-27 10:36:24] [progress] iter 49250/50000 | loss=0.1426 | n_gaussians=130073 | 20.28 it/s | ETA=0:00:36 | lr_xyz=1.75e-06
# Training:  99%|▉| 49299/50000 [51:39<00:34, 20.10it/s, loss=0.143, n_gaussians=1[2026-07-27 10:36:27] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  99%|▉| 49299/50000 [51:39<00:34, 20.10it/s, loss=0.141, n_gaussians=1[2026-07-27 10:36:27] [progress] iter 49300/50000 | loss=0.1414 | n_gaussians=130073 | 19.78 it/s | ETA=0:00:35 | lr_xyz=1.75e-06
# Training:  99%|▉| 49349/50000 [51:41<00:32, 20.01it/s, loss=0.133, n_gaussians=1[2026-07-27 10:36:29] [progress] iter 49350/50000 | loss=0.1328 | n_gaussians=130073 | 20.24 it/s | ETA=0:00:32 | lr_xyz=1.75e-06
# Training:  99%|▉| 49398/50000 [51:44<00:30, 19.96it/s, loss=0.133, n_gaussians=1[2026-07-27 10:36:32] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  99%|▉| 49398/50000 [51:44<00:30, 19.96it/s, loss=0.0872, n_gaussians=[2026-07-27 10:36:32] [progress] iter 49400/50000 | loss=0.0872 | n_gaussians=130073 | 19.75 it/s | ETA=0:00:30 | lr_xyz=1.75e-06
# Training:  99%|▉| 49448/50000 [51:46<00:27, 20.14it/s, loss=0.103, n_gaussians=1[2026-07-27 10:36:34] [progress] iter 49450/50000 | loss=0.1031 | n_gaussians=130073 | 20.32 it/s | ETA=0:00:27 | lr_xyz=1.75e-06
# Training:  99%|▉| 49497/50000 [51:49<00:25, 19.89it/s, loss=0.103, n_gaussians=1[2026-07-27 10:36:37] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  99%|▉| 49497/50000 [51:49<00:25, 19.89it/s, loss=0.0954, n_gaussians=[2026-07-27 10:36:37] [progress] iter 49500/50000 | loss=0.0954 | n_gaussians=130073 | 19.58 it/s | ETA=0:00:25 | lr_xyz=1.75e-06
# Training:  99%|▉| 49548/50000 [51:51<00:22, 20.00it/s, loss=0.0858, n_gaussians=[2026-07-27 10:36:39] [progress] iter 49550/50000 | loss=0.0858 | n_gaussians=130073 | 20.28 it/s | ETA=0:00:22 | lr_xyz=1.75e-06
# Training:  99%|▉| 49599/50000 [51:54<00:19, 20.10it/s, loss=0.0858, n_gaussians=[2026-07-27 10:36:42] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  99%|▉| 49599/50000 [51:54<00:19, 20.10it/s, loss=0.142, n_gaussians=1[2026-07-27 10:36:42] [progress] iter 49600/50000 | loss=0.1418 | n_gaussians=130073 | 19.69 it/s | ETA=0:00:20 | lr_xyz=1.75e-06
# Training:  99%|▉| 49649/50000 [51:56<00:17, 20.01it/s, loss=0.0885, n_gaussians=[2026-07-27 10:36:44] [progress] iter 49650/50000 | loss=0.0885 | n_gaussians=130073 | 20.24 it/s | ETA=0:00:17 | lr_xyz=1.75e-06
# Training:  99%|▉| 49697/50000 [51:59<00:15, 20.04it/s, loss=0.0885, n_gaussians=[2026-07-27 10:36:47] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training:  99%|▉| 49697/50000 [51:59<00:15, 20.04it/s, loss=0.0922, n_gaussians=[2026-07-27 10:36:47] [progress] iter 49700/50000 | loss=0.0922 | n_gaussians=130073 | 19.87 it/s | ETA=0:00:15 | lr_xyz=1.75e-06
# Training:  99%|▉| 49748/50000 [52:01<00:12, 20.03it/s, loss=0.141, n_gaussians=1[2026-07-27 10:36:49] [progress] iter 49750/50000 | loss=0.1406 | n_gaussians=130073 | 20.23 it/s | ETA=0:00:12 | lr_xyz=1.75e-06
# Training: 100%|▉| 49798/50000 [52:04<00:10, 20.00it/s, loss=0.141, n_gaussians=1[2026-07-27 10:36:52] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training: 100%|▉| 49798/50000 [52:04<00:10, 20.00it/s, loss=0.132, n_gaussians=1[2026-07-27 10:36:52] [progress] iter 49800/50000 | loss=0.1324 | n_gaussians=130073 | 19.62 it/s | ETA=0:00:10 | lr_xyz=1.75e-06
# Training: 100%|▉| 49849/50000 [52:06<00:07, 19.92it/s, loss=0.0916, n_gaussians=[2026-07-27 10:36:54] [progress] iter 49850/50000 | loss=0.0916 | n_gaussians=130073 | 20.21 it/s | ETA=0:00:07 | lr_xyz=1.75e-06
# Training: 100%|▉| 49899/50000 [52:09<00:05, 19.84it/s, loss=0.0916, n_gaussians=[2026-07-27 10:36:57] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training: 100%|▉| 49899/50000 [52:09<00:05, 19.84it/s, loss=0.134, n_gaussians=1[2026-07-27 10:36:57] [progress] iter 49900/50000 | loss=0.1341 | n_gaussians=130073 | 19.76 it/s | ETA=0:00:05 | lr_xyz=1.75e-06
# Training: 100%|▉| 49948/50000 [52:11<00:02, 20.08it/s, loss=0.14, n_gaussians=13[2026-07-27 10:36:59] [progress] iter 49950/50000 | loss=0.1402 | n_gaussians=130073 | 20.27 it/s | ETA=0:00:02 | lr_xyz=1.75e-06
# Training: 100%|▉| 49998/50000 [52:14<00:00, 20.24it/s, loss=0.14, n_gaussians=13[2026-07-27 10:37:02] [prune SAFETY] REFUSED: this prune would remove 130073/130073 Gaussians, leaving only 0 (below the floor of 1000). Skipping it entirely rather than risk collapsing to (near) zero Gaussians, which crashes the next render call with a native CUDA SIGFPE instead of a catchable Python error. This almost always means a prune criterion is miscalibrated for this scene - most likely 'pruning.max_distance_from_center': for aerial/drone data the camera-orbit radius (what 'extent' is computed from) can be smaller than the footprint of the actual structure being photographed, so a heuristic tuned as a multiple of camera extent can flag real geometry as 'too far from center' just as easily as it flags genuine sky floaters. Try raising max_distance_from_center substantially, or set it to null to disable, and check 'pruning.size.max_world_ratio' / 'densify.min_world_size_ratio' too.
# Training: 100%|▉| 49998/50000 [52:14<00:00, 20.24it/s, loss=0.0945, n_gaussians=[2026-07-27 10:37:02] [progress] iter 50000/50000 | loss=0.0945 | n_gaussians=130073 | 19.76 it/s | ETA=0:00:00 | lr_xyz=1.75e-06
# [2026-07-27 10:37:13] [eval @ iter 50000] psnr=20.3315, ssim=0.6221, lpips=0.4215
# [2026-07-27 10:37:13] Saved checkpoint: /kaggle/working/outputs/bts_scene_01/checkpoints/iter_50000.pth
# Training: 100%|█| 50000/50000 [52:25<00:00, 15.89it/s, loss=0.0945, n_gaussians=
# [2026-07-27 10:37:13] Saved checkpoint: /kaggle/working/outputs/bts_scene_01/checkpoints/last.pth
# [2026-07-27 10:37:14] Training complete.
# [2026-07-27 10:37:14] Starting target novel view rendering...
# [2026-07-27 10:37:43] Rendered 60 novel view images to /kaggle/working/outputs/bts_scene_01/novel_views
# [2026-07-27 10:37:43] Mean alpha (opacity coverage) across novel views: 0.9169 (min: 0.8616). Low values (<0.3) strongly suggest these cameras are pointed at regions with sparse/no reconstructed geometry, or are positioned much farther from the scene than train cameras.
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1320, 989) to (1328, 992) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Saved preview video: /kaggle/working/outputs/bts_scene_01/novel_views/novel_views.mp4

# %%
# !python -m inference.render_novel_views --config configs/default.kaggle.yaml --checkpoint /kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth
# Out:
# [2026-07-27 10:37:59] Loaded checkpoint '/kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth' at iteration 25000, 130073 Gaussians
# [ColmapLoader] Filtered out 33486/218846 noisy points.
# [BTSDataset] WARNING: 158/398 images are listed in the sparse reconstruction but were NOT found in '/kaggle/input/datasets/lthuhong/round2/HCM0539/train/images': DJI_20241229165804_0012_V.JPG, DJI_20241229165813_0021_V.JPG, DJI_20241229165814_0022_V.JPG, DJI_20241229165817_0025_V.JPG, DJI_20241229165818_0026_V.JPG, ... (+153 more)
# These images are SKIPPED from the train/eval split (this is not a code bug - check the source dataset if the number missing is unexpectedly large).
# Rendering novel views: 100%|████████████████████| 60/60 [00:02<00:00, 26.11it/s]
# [2026-07-27 10:38:12] Rendered 60 novel view images to ./outputs/bts_scene_01/novel_views
# [2026-07-27 10:38:12] Mean alpha (opacity coverage) across novel views: 0.9222 (min: 0.8649). Low values (<0.3) strongly suggest these cameras are pointed at regions with sparse/no reconstructed geometry, or are positioned much farther from the scene than train cameras - not an undertrained-model or color issue.
# [2026-07-27 10:38:13] [submission] Zipped 60 images into: ./outputs/bts_scene_01/submission.zip
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1320, 989) to (1328, 992) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Saved preview video: ./outputs/bts_scene_01/novel_views/novel_views.mp4
