# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/lthuhong/round2/HCM0644/README.txt
# /kaggle/input/datasets/lthuhong/round2/HCM0644/test/test_poses.csv
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229084143_0369_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229084040_0327_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229083233_0074_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229083144_0050_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229084147_0373_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229083438_0170_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229084150_0376_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229084101_0344_V.JPG
# /kaggle/input/datasets/lthuhong/round2/HCM0644/train/images/DJI_20241229083140_0046_V.JPG
# ...

# %%
# !git clone --branch honbell https://github.com/LeeDerHerbsjaune/Kamikaze_BTS_2026_AIRace.git
# %cd Kamikaze_BTS_2026_AIRace
# Out:
# Cloning into 'Kamikaze_BTS_2026_AIRace'...
# remote: Enumerating objects: 1155, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 1155 (delta 136), reused 163 (delta 102), pack-reused 934 (from 1)
# Receiving objects: 100% (1155/1155), 8.76 MiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (548/548), done.
# /kaggle/working/Kamikaze_BTS_2026_AIRace

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 64.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 100.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

print("🔍 Đang tìm kiếm thư mục 'root' phù hợp trong /kaggle/input...\n")

matching_roots = []

# Duyệt qua toàn bộ /kaggle/input
for root, dirs, files in os.walk("/kaggle/input"):
    # Kiểm tra nếu thư mục hiện tại chứa cả thư mục con 'images' và 'sparse'
    if "images" in dirs and "sparse" in dirs:
        matching_roots.append(root)

if matching_roots:
    print("✅ Đã tìm thấy đường dẫn root thích hợp:")
    for path in matching_roots:
        print("-" * 50)
        print(f'dataset:\n  root: "{path}"')
        print("-" * 50)
else:
    print("⚠️ Không tìm thấy thư mục nào chứa đồng thời cả 'images' và 'sparse'.")
    print("Dưới đây là toàn bộ cấu trúc thư mục trong /kaggle/input để bạn kiểm tra:\n")
    for root, dirs, files in os.walk("/kaggle/input"):
        print(root)
# Out:
# 🔍 Đang tìm kiếm thư mục 'root' phù hợp trong /kaggle/input...
#
# ✅ Đã tìm thấy đường dẫn root thích hợp:
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0644/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0674/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0421/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/bonsai/train"
# --------------------------------------------------
# --------------------------------------------------
# dataset:
#   root: "/kaggle/input/datasets/lthuhong/round2/HCM0540/train"
# ...

# %%
# !python train.py --config configs/default.kaggle.yaml
# Out:
# [2026-07-27 10:52:53] Starting experiment: bts_scene_01
# [2026-07-27 10:52:53] Loading dataset (drone images + camera poses)...
# [ColmapLoader] Filtered out 27573/171304 noisy points.
# [BTSDataset] WARNING: 110/350 images are listed in the sparse reconstruction but were NOT found in '/kaggle/input/datasets/lthuhong/round2/HCM0421/train/images': DJI_20241230093347_0009_V.JPG, DJI_20241230093355_0017_V.JPG, DJI_20241230093357_0019_V.JPG, DJI_20241230093405_0027_V.JPG, DJI_20241230093418_0040_V.JPG, ... (+105 more)
# These images are SKIPPED from the train/eval split (this is not a code bug - check the source dataset if the number missing is unexpectedly large).
# [2026-07-27 10:53:08] Train views: 216, Eval views: 24, Target novel views: 60
# Saved camera trajectory plot: /kaggle/working/outputs/bts_scene_01/camera_trajectory.png
# [2026-07-27 10:53:08] Initializing Gaussian Model from the point cloud...
# [2026-07-27 10:53:13] Initialized 143731 Gaussians
# ...

# %%
# !python -m inference.render_novel_views --config configs/default.kaggle.yaml --checkpoint /kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth
# Out:
# [2026-07-27 11:42:46] Loaded checkpoint '/kaggle/working/outputs/bts_scene_01/checkpoints/iter_25000.pth' at iteration 25000, 100709 Gaussians
# [ColmapLoader] Filtered out 27573/171304 noisy points.
# [BTSDataset] WARNING: 110/350 images are listed in the sparse reconstruction but were NOT found in '/kaggle/input/datasets/lthuhong/round2/HCM0421/train/images': DJI_20241230093347_0009_V.JPG, DJI_20241230093355_0017_V.JPG, DJI_20241230093357_0019_V.JPG, DJI_20241230093405_0027_V.JPG, DJI_20241230093418_0040_V.JPG, ... (+105 more)
# These images are SKIPPED from the train/eval split (this is not a code bug - check the source dataset if the number missing is unexpectedly large).
# Rendering novel views: 100%|████████████████████| 60/60 [00:02<00:00, 25.33it/s]
# [2026-07-27 11:42:58] Rendered 60 novel view images to ./outputs/bts_scene_01/novel_views
# ...
